# %% [markdown]
# # Junior ML Classification
#
# Inspect the synthetic SLA-risk classification dataset.

# %%
from pathlib import Path
    import pandas as pd

    data_path = Path("..") / "data" / "sample_synthetic_data.csv"
    df = pd.read_csv(data_path)
    display(df.head())
    display(df.describe(include="all").transpose().head(12))
    display(df["sla_risk"].value_counts(normalize=True).rename("class_share"))
